# %% [markdown]
# # NBO/NBA PoC – Notebook (V3)
# Carregue as saídas do pipeline e explore métricas e decisões NBA.

# %%
import json, pandas as pd
metrics = json.load(open('outputs/metrics.json', 'r', encoding='utf-8'))
metrics

# %%
scored = pd.read_csv('outputs/scored_with_nba.csv', parse_dates=['ref_date'])
scored[['customer_id','p_churn_90d','p_convert_30d','ltv_12m_hat','nba_decision']].head()
